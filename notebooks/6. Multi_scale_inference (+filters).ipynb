# %%
# Установка
# !pip -q install ultralytics shapely opencv-python
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.0 MB/s eta 0:00:00

# %%
# =========================
# TRAIN MULTI-GSD + ADAPTIVE CONF + 3-SCALE INFERENCE
# + TILE BATCHING + MEANS + CHECKPOINTS
# =========================

import os, glob, random
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm
from ultralytics import YOLO
import math

# -------------------------
# Google Drive mount
# -------------------------
from google.colab import drive
drive.mount('/content/drive')

# -------------------------
# Repro
# -------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# =========================
# Unzip dataset from Google Drive
# =========================
ZIP_ON_DRIVE = "/content/drive/MyDrive/dataset.zip"
OUT_ZIP = "/content/dataset.zip"
OUT_DIR = "/content/dataset"

assert os.path.exists(ZIP_ON_DRIVE), f"Dataset zip not found on Drive: {ZIP_ON_DRIVE}"

# !cp -v "{ZIP_ON_DRIVE}" "{OUT_ZIP}"
# !mkdir -p "{OUT_DIR}"
# !unzip -q "{OUT_ZIP}" -d "{OUT_DIR}"
print("dataset dir:", OUT_DIR)

IMG_DIR  = os.path.join(OUT_DIR, "images")
MASK_DIR = os.path.join(OUT_DIR, "gt")

assert os.path.isdir(IMG_DIR),  f"Missing images dir: {IMG_DIR}"
assert os.path.isdir(MASK_DIR), f"Missing gt dir: {MASK_DIR}"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Mounted at /content/drive
# '/content/drive/MyDrive/dataset.zip' -> '/content/dataset.zip'

# %%
# -------------------------
# Split function
# -------------------------
def split_by_scene(imgs, val_ratio=0.15, seed=42):
    rng = random.Random(seed)
    idxs = list(range(len(imgs)))
    rng.shuffle(idxs)
    n_val = max(1, int(len(imgs) * val_ratio))
    val = set(idxs[:n_val])

    train_imgs = [p for i, p in enumerate(imgs) if i not in val]
    val_imgs   = [p for i, p in enumerate(imgs) if i in val]
    return train_imgs, val_imgs

# =========================
# Detection settings
# =========================
MODEL_WEIGHTS = "yolo26x-obb.pt"
CAR_CLASS_ID = 10

TILE_SIZE = 1024
OVERLAP = 0.1

# adaptive thresholds
CONF_PRIMARY  = 0.10
CONF_FALLBACK = 0.01  # <-- fallback: более низкий порог

IOU_THRES_TILE = 0.5

DEVICE = None
HALF = True

MERGE_CELL_PX = 3

# -------------------------
# Tile batching
# -------------------------
TILE_BATCH = 16  # <-- батчинг

# =========================
# Aspect ratio filtering (car-like boxes)
# =========================
ASPECT_RATIO_MIN = 1.2
ASPECT_RATIO_MAX = 3.8

def filter_detections_by_aspect_ratio(detections, rmin=1.2, rmax=3.8):
    """
    Keep only detections where ratio = max(w,h)/min(w,h) is in [rmin, rmax]
    """
    if not detections:
        return []

    out = []
    for d in detections:
        w = float(d.get("w", 0.0))
        h = float(d.get("h", 0.0))
        if w <= 0 or h <= 0:
            continue

        L = max(w, h)
        W = min(w, h)
        if W <= 0:
            continue

        ratio = L / W
        if rmin <= ratio <= rmax:
            out.append(d)

    return out

# -------------------------
# Фильтр аномальных размеров
# -------------------------

def filter_detections_by_sqrtLW_iqr(detections, k=1.5):
    """
    IQR filter on sqrt(L*W) to remove outlier boxes.
    Keeps values within [Q1-k*IQR, Q3+k*IQR].
    """
    if not detections or len(detections) < 6:
        return detections

    w = np.array([d["w"] for d in detections], dtype=np.float32)
    h = np.array([d["h"] for d in detections], dtype=np.float32)

    L = np.maximum(w, h)
    W = np.minimum(w, h)
    s = np.sqrt(L * W)

    q1 = np.percentile(s, 25)
    q3 = np.percentile(s, 75)
    iqr = q3 - q1

    lo = q1 - k * iqr
    hi = q3 + k * iqr

    out = []
    for d in detections:
        Ld = max(d["w"], d["h"])
        Wd = min(d["w"], d["h"])
        sd = math.sqrt(Ld * Wd)

        if lo <= sd <= hi:
            out.append(d)

    return out

# -------------------------
# GSD logic
# -------------------------
GSD_BASE_M_PER_PX = 0.3  # базовый масштаб датасета
GSD_TARGETS = [0.1, 0.2, 0.29, 0.4, 0.5, 0.6, 0.7]
print("GSD targets:", GSD_TARGETS)

# -------------------------
# Multi-scale inference params
# -------------------------
MIN_CARS_FOR_ANALYSIS_1 = 6
MIN_CARS_FOR_ANALYSIS_2 = 4  # <-- важно: не 1
TYPICAL_CAR_SQRTLW_M = 3.2  # sqrt(L*W) типичной машины в метрах (для первичной грубой оценки)

CHECKPOINT_EVERY_IMAGES = 20

# =========================
# Load model
# =========================
model = YOLO(MODEL_WEIGHTS)

# =========================
# Tile generator
# =========================
def generate_tiles(img_bgr: np.ndarray, tile_size: int, overlap: float):
    assert 0 <= overlap < 1
    stride = int(tile_size * (1 - overlap))
    stride = max(1, stride)

    H, W = img_bgr.shape[:2]
    xs = list(range(0, W, stride))
    ys = list(range(0, H, stride))

    for y0 in ys:
        for x0 in xs:
            x1 = min(x0 + tile_size, W)
            y1 = min(y0 + tile_size, H)

            tile = img_bgr[y0:y1, x0:x1]
            pad_right = tile_size - (x1 - x0)
            pad_bottom = tile_size - (y1 - y0)

            if pad_right > 0 or pad_bottom > 0:
                tile = cv2.copyMakeBorder(
                    tile, 0, pad_bottom, 0, pad_right,
                    borderType=cv2.BORDER_CONSTANT, value=(0, 0, 0)
                )

            yield (x0, y0, x1, y1, tile)

# =========================
# Extract OBB xywhr
# =========================
def extract_detections_xywhr(result, keep_class_id=None):
    dets = []
    if not hasattr(result, "obb") or result.obb is None:
        return dets

    obb = result.obb
    boxes = obb.xywhr.cpu().numpy()  # (N,5): cx,cy,w,h,angle
    conf = obb.conf.cpu().numpy() if hasattr(obb, "conf") else None
    cls  = obb.cls.cpu().numpy().astype(int) if hasattr(obb, "cls") else None

    n = boxes.shape[0]
    for i in range(n):
        c = int(cls[i]) if cls is not None else -1
        if keep_class_id is not None and c != keep_class_id:
            continue

        dets.append({
            "cx": float(boxes[i, 0]),
            "cy": float(boxes[i, 1]),
            "w":  float(boxes[i, 2]),
            "h":  float(boxes[i, 3]),
            "angle": float(boxes[i, 4]),
            "conf": float(conf[i]) if conf is not None else 0.0,
            "cls": c
        })

    return dets

# =========================
# Fast merge duplicates by center hash
# =========================
def merge_xywhr_by_center_hash(detections, cell=12):
    if not detections:
        return []

    best = {}  # (gx,gy) -> det

    for d in detections:
        gx = int(d["cx"] // cell)
        gy = int(d["cy"] // cell)

        winner_key = None
        winner_conf = -1.0

        for dx in (-1, 0, 1):
            for dy in (-1, 0, 1):
                k = (gx + dx, gy + dy)
                if k in best and best[k]["conf"] > winner_conf:
                    winner_conf = best[k]["conf"]
                    winner_key = k

        if winner_key is None:
            best[(gx, gy)] = d
        else:
            if d["conf"] > best[winner_key]["conf"]:
                best[winner_key] = d

    return list(best.values())

# =========================
# Resize image for a target GSD
# resize_factor = GSD_BASE / GSD_TARGET
# =========================
def resize_to_gsd(img_bgr: np.ndarray, gsd_target: float, gsd_base: float = 0.3):
    resize_factor = gsd_base / gsd_target
    H, W = img_bgr.shape[:2]
    newW = max(1, int(round(W * resize_factor)))
    newH = max(1, int(round(H * resize_factor)))

    if abs(resize_factor - 1.0) < 1e-9:
        return img_bgr, 1.0

    interp = cv2.INTER_CUBIC if resize_factor > 1.0 else cv2.INTER_AREA
    img_resized = cv2.resize(img_bgr, (newW, newH), interpolation=interp)
    return img_resized, float(resize_factor)

# =========================
# Generic resize by factor (for multi-scale inference)
# =========================
def resize_by_factor(img_bgr: np.ndarray, factor: float):
    assert factor > 0
    if abs(factor - 1.0) < 1e-9:
        return img_bgr

    H, W = img_bgr.shape[:2]
    newW = max(1, int(round(W * factor)))
    newH = max(1, int(round(H * factor)))

    interp = cv2.INTER_CUBIC if factor > 1.0 else cv2.INTER_AREA
    return cv2.resize(img_bgr, (newW, newH), interpolation=interp)

# =========================
# Compute object medians + means (pixels)
# =========================
def compute_medians_means_pixels(merged):
    """
    For each detection:
      L = max(w,h)
      W = min(w,h)
      sqrtLW = sqrt(L*W)
    Returns:
      med_len, med_wid, med_sqrtLW,
      mean_len, mean_wid, mean_sqrtLW,
      count
    """
    if not merged:
        return {
            "median_length_px": np.nan,
            "median_width_px":  np.nan,
            "median_sqrtLW_px": np.nan,
            "mean_length_px": np.nan,
            "mean_width_px":  np.nan,
            "mean_sqrtLW_px": np.nan,
            "count": 0
        }

    w = np.array([d["w"] for d in merged], dtype=np.float32)
    h = np.array([d["h"] for d in merged], dtype=np.float32)

    lengths = np.maximum(w, h)
    widths  = np.minimum(w, h)
    sqrtLW  = np.sqrt(lengths * widths)

    return {
        "median_length_px": float(np.median(lengths)),
        "median_width_px":  float(np.median(widths)),
        "median_sqrtLW_px": float(np.median(sqrtLW)),
        "mean_length_px": float(np.mean(lengths)),
        "mean_width_px":  float(np.mean(widths)),
        "mean_sqrtLW_px": float(np.mean(sqrtLW)),
        "count": int(len(merged))
    }

# =========================
# Choose 3 scales based on estimated GSD
# <=0.20 -> [1.0, 0.5, 0.3]
# (0.20,0.35] -> [1.0, 0.5, 2.0]
# (0.35,0.50] -> [1.0, 0.7, 2.0]
# >0.50 -> [1.0, 1.5, 2.5]
# =========================
def choose_three_scales(gsd_est: float):
    if not np.isfinite(gsd_est) or gsd_est <= 0:
        return [1.0, 0.5, 2.0]

    if gsd_est <= 0.20:
        return [1.0, 0.5, 0.3]
    elif gsd_est <= 0.35:
        return [1.0, 0.5, 2.0]
    elif gsd_est <= 0.50:
        return [1.0, 0.7, 2.0]
    else:
        return [1.0, 1.5, 2.5]

# =========================
# Detect image tiled with BATCHING
# =========================
def detect_image_tiled_batched(img_bgr: np.ndarray, conf_thres: float, batch_size: int = 8):
    H, W = img_bgr.shape[:2]
    all_dets_global = []

    batch_tiles_rgb = []
    batch_offsets = []  # (x0,y0)

    def run_batch():
        nonlocal batch_tiles_rgb, batch_offsets, all_dets_global
        if not batch_tiles_rgb:
            return

        results = model.predict(
            source=batch_tiles_rgb,   # list of images
            imgsz=TILE_SIZE,
            conf=conf_thres,
            iou=IOU_THRES_TILE,
            device=DEVICE,
            half=HALF,
            classes=[CAR_CLASS_ID] if CAR_CLASS_ID is not None else None,
            verbose=False
        )

        # results is list aligned with input tiles
        for r0, (x0, y0) in zip(results, batch_offsets):
            dets_tile = extract_detections_xywhr(r0, keep_class_id=CAR_CLASS_ID)

            for d in dets_tile:
                cx = d["cx"] + x0
                cy = d["cy"] + y0

                if cx < 0 or cy < 0 or cx >= W or cy >= H:
                    continue

                all_dets_global.append({
                    "cx": cx, "cy": cy,
                    "w": d["w"], "h": d["h"],
                    "angle": d["angle"],
                    "conf": d["conf"],
                    "cls": d["cls"],
                })

        batch_tiles_rgb = []
        batch_offsets = []

    # collect tiles
    for x0, y0, x1, y1, tile_bgr in generate_tiles(img_bgr, TILE_SIZE, OVERLAP):
        tile_rgb = cv2.cvtColor(tile_bgr, cv2.COLOR_BGR2RGB)
        batch_tiles_rgb.append(tile_rgb)
        batch_offsets.append((x0, y0))

        if len(batch_tiles_rgb) >= batch_size:
            run_batch()

    # flush remainder
    run_batch()

    merged = merge_xywhr_by_center_hash(all_dets_global, cell=MERGE_CELL_PX)
    return merged

# =========================
# Multi-scale inference using EXISTING base detections/stats
# + aspect ratio filtering on scale2/scale3
# Outputs normalized back to base scale (divide by factor)
# =========================
def multi_scale_inference_from_base(
    img_base_bgr: np.ndarray,
    conf_used: float,
    merged_base,
    stats_base
):
    """
    base scale = 1.0 already computed outside (merged_base, stats_base)
    1) estimate gsd from median_sqrtLW_px assuming typical sqrtLW=3.2m
       gsd_est ≈ 3.2 / median_sqrtLW_px  [m/px]
    2) choose 2 additional scales
    3) run detection on scale2 & scale3
    4) normalize medians/means back to base scale by dividing by factor

    IMPORTANT:
    - scale1 stats_base are assumed to be already computed from FILTERED merged_base (done outside).
    - scale2/scale3 detections are filtered here:
        1) aspect ratio
        2) sqrtLW IQR filter
    """

    # -------------------------
    # base stats (scale 1.0)
    # -------------------------
    count1 = stats_base["count"]
    medS1 = stats_base["median_sqrtLW_px"]

    if np.isfinite(medS1) and medS1 > 0:
        gsd_est = float(TYPICAL_CAR_SQRTLW_M / medS1)
    else:
        gsd_est = np.nan

    scales = choose_three_scales(gsd_est)
    if len(scales) != 3:
        scales = [1.0, 0.5, 2.0]

    def norm(value_px, factor):
        if not np.isfinite(value_px):
            return np.nan
        return float(value_px / factor)

    def apply_filters(dets):
        """Apply filters in the correct order: aspect ratio -> IQR on sqrtLW."""
        dets = filter_detections_by_aspect_ratio(
            dets,
            rmin=ASPECT_RATIO_MIN,
            rmax=ASPECT_RATIO_MAX
        )
        dets = filter_detections_by_sqrtLW_iqr(dets, k=1.5)
        return dets

    out = {
        "conf_used": float(conf_used),
        "count_used": int(count1),
        "gsd_est_m_per_px": float(gsd_est) if np.isfinite(gsd_est) else np.nan,
        "scale_1": float(scales[0]),
        "scale_2": float(scales[1]),
        "scale_3": float(scales[2]),
    }

    # -------------------------
    # scale 1 (already computed & already filtered outside)
    # -------------------------
    out.update({
        "med_len_s1_px":     norm(stats_base["median_length_px"], scales[0]),
        "med_wid_s1_px":     norm(stats_base["median_width_px"],  scales[0]),
        "med_sqrtLW_s1_px":  norm(stats_base["median_sqrtLW_px"], scales[0]),
        "mean_len_s1_px":    norm(stats_base["mean_length_px"],   scales[0]),
        "mean_wid_s1_px":    norm(stats_base["mean_width_px"],    scales[0]),
        "mean_sqrtLW_s1_px": norm(stats_base["mean_sqrtLW_px"],   scales[0]),
        "count_s1": int(stats_base["count"])
    })

    # -------------------------
    # scale 2
    # -------------------------
    img2 = resize_by_factor(img_base_bgr, scales[1])
    merged2 = detect_image_tiled_batched(
        img2,
        conf_thres=conf_used,
        batch_size=TILE_BATCH
    )

    merged2 = apply_filters(merged2)
    st2 = compute_medians_means_pixels(merged2)

    out.update({
        "med_len_s2_px":     norm(st2["median_length_px"], scales[1]),
        "med_wid_s2_px":     norm(st2["median_width_px"],  scales[1]),
        "med_sqrtLW_s2_px":  norm(st2["median_sqrtLW_px"], scales[1]),
        "mean_len_s2_px":    norm(st2["mean_length_px"],   scales[1]),
        "mean_wid_s2_px":    norm(st2["mean_width_px"],    scales[1]),
        "mean_sqrtLW_s2_px": norm(st2["mean_sqrtLW_px"],   scales[1]),
        "count_s2": int(st2["count"])
    })

    # -------------------------
    # scale 3
    # -------------------------
    img3 = resize_by_factor(img_base_bgr, scales[2])
    merged3 = detect_image_tiled_batched(
        img3,
        conf_thres=conf_used,
        batch_size=TILE_BATCH
    )

    merged3 = apply_filters(merged3)
    st3 = compute_medians_means_pixels(merged3)

    out.update({
        "med_len_s3_px":     norm(st3["median_length_px"], scales[2]),
        "med_wid_s3_px":     norm(st3["median_width_px"],  scales[2]),
        "med_sqrtLW_s3_px":  norm(st3["median_sqrtLW_px"], scales[2]),
        "mean_len_s3_px":    norm(st3["mean_length_px"],   scales[2]),
        "mean_wid_s3_px":    norm(st3["mean_width_px"],    scales[2]),
        "mean_sqrtLW_s3_px": norm(st3["mean_sqrtLW_px"],   scales[2]),
        "count_s3": int(st3["count"])
    })

    return out

# =========================
# Collect images
# =========================
img_exts = ("*.tif",)
all_imgs = []
for e in img_exts:
    all_imgs += glob.glob(os.path.join(IMG_DIR, e))
all_imgs = sorted(all_imgs)

assert len(all_imgs) > 0, f"No images found in: {IMG_DIR}"

train_imgs, val_imgs = split_by_scene(all_imgs, val_ratio=0.15, seed=SEED)

print("Total images:", len(all_imgs))
print("Train images:", len(train_imgs))
print("Val images:", len(val_imgs))

# =========================
# Output paths (final + checkpoints)
# =========================
OUT_CSV  = "/content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels.csv"
OUT_XLSX = "/content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels.xlsx"

OUT_CSV_PART  = "/content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.csv"
OUT_XLSX_PART = "/content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.xlsx"
# Out:
# GSD targets: [0.1, 0.2, 0.29, 0.4, 0.5, 0.6, 0.7]
# Total images: 180
# Train images: 153
# Val images: 27

# %%
# =========================
# Run TRAIN only, multi-GSD + adaptive conf + 3-scale inference
# (with aspect-ratio filtering before stats)
# MAX прогонов на один gsd:
#   Успех на 0.10: 1 (base) + 2 (scale2/scale3) = 3
#   Успех на 0.01: 1 (base 0.10) + 1 (base 0.01) + 2 = 4
#   Провал: 1 (0.10) + 1 (0.01) = 2
# =========================
total_iters = len(train_imgs) * len(GSD_TARGETS)
pbar = tqdm(total=total_iters, desc="Processing TRAIN (image x GSD)")

rows = []
processed_images = 0

for img_path in train_imgs:
    img0 = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if img0 is None:
        pbar.update(len(GSD_TARGETS))
        processed_images += 1
        continue

    image_name = os.path.basename(img_path)

    for gsd_target in GSD_TARGETS:
        img_gsd, resize_factor = resize_to_gsd(
            img0,
            gsd_target=gsd_target,
            gsd_base=GSD_BASE_M_PER_PX
        )

        # -------------------------
        # PRIMARY pass (conf=0.10)
        # -------------------------
        merged_p_raw = detect_image_tiled_batched(
            img_gsd,
            conf_thres=CONF_PRIMARY,
            batch_size=TILE_BATCH
        )

        # aspect-ratio filtering BEFORE stats
        merged_p = filter_detections_by_aspect_ratio(
            merged_p_raw,
            rmin=ASPECT_RATIO_MIN,
            rmax=ASPECT_RATIO_MAX
        )
        merged_p = filter_detections_by_sqrtLW_iqr(merged_p, k=1.5)

        stats_p = compute_medians_means_pixels(merged_p)
        count_primary = stats_p["count"]

        metrics = None
        count_fallback = 0  # default

        if count_primary >= MIN_CARS_FOR_ANALYSIS_1:
            # multi-scale using already computed base (filtered detections & stats)
            metrics = multi_scale_inference_from_base(
                img_base_bgr=img_gsd,
                conf_used=CONF_PRIMARY,
                merged_base=merged_p,
                stats_base=stats_p
            )

        else:
            # -------------------------
            # FALLBACK pass (более низкий порог)
            # -------------------------
            merged_f_raw = detect_image_tiled_batched(
                img_gsd,
                conf_thres=CONF_FALLBACK,
                batch_size=TILE_BATCH
            )

            # aspect-ratio filtering BEFORE stats
            merged_f = filter_detections_by_aspect_ratio(
                merged_f_raw,
                rmin=ASPECT_RATIO_MIN,
                rmax=ASPECT_RATIO_MAX
            )
            merged_f = filter_detections_by_sqrtLW_iqr(merged_f, k=1.5)

            stats_f = compute_medians_means_pixels(merged_f)
            count_fallback = stats_f["count"]

            if count_fallback >= MIN_CARS_FOR_ANALYSIS_2:
                metrics = multi_scale_inference_from_base(
                    img_base_bgr=img_gsd,
                    conf_used=CONF_FALLBACK,
                    merged_base=merged_f,
                    stats_base=stats_f
                )
            else:
                # give up (not enough car-like detections)
                metrics = {
                    "conf_used": np.nan,
                    "count_used": int(count_fallback),
                    "gsd_est_m_per_px": np.nan,
                    "scale_1": np.nan, "scale_2": np.nan, "scale_3": np.nan,

                    "med_len_s1_px": np.nan, "med_wid_s1_px": np.nan, "med_sqrtLW_s1_px": np.nan,
                    "mean_len_s1_px": np.nan, "mean_wid_s1_px": np.nan, "mean_sqrtLW_s1_px": np.nan,
                    "count_s1": int(count_fallback),

                    "med_len_s2_px": np.nan, "med_wid_s2_px": np.nan, "med_sqrtLW_s2_px": np.nan,
                    "mean_len_s2_px": np.nan, "mean_wid_s2_px": np.nan, "mean_sqrtLW_s2_px": np.nan,
                    "count_s2": 0,

                    "med_len_s3_px": np.nan, "med_wid_s3_px": np.nan, "med_sqrtLW_s3_px": np.nan,
                    "mean_len_s3_px": np.nan, "mean_wid_s3_px": np.nan, "mean_sqrtLW_s3_px": np.nan,
                    "count_s3": 0,
                }

        rows.append({
            "image_name": image_name,
            "gsd_m_per_px": float(gsd_target),
            "resize_factor": float(resize_factor),

            # overlap + batching info (чтобы потом не гадать)
            "tile_size": int(TILE_SIZE),
            "overlap": float(OVERLAP),
            "tile_batch": int(TILE_BATCH),

            # adaptive decision info
            "conf_primary": float(CONF_PRIMARY),
            "count_primary": int(count_primary),
            "conf_fallback": float(CONF_FALLBACK),
            "count_fallback": int(count_fallback),

            # multi-scale output (or NaNs)
            **metrics
        })

        pbar.update(1)

    processed_images += 1

    # =========================
    # Checkpoint save every N images
    # =========================
    if processed_images % CHECKPOINT_EVERY_IMAGES == 0:
        df_part = pd.DataFrame(rows)
        df_part = df_part.sort_values(["image_name", "gsd_m_per_px"]).reset_index(drop=True)

        df_part.to_csv(OUT_CSV_PART, index=False)
        df_part.to_excel(OUT_XLSX_PART, index=False)

        print(f"\n[Checkpoint] Saved partial after {processed_images} images:")
        print("CSV :", OUT_CSV_PART)
        print("XLSX:", OUT_XLSX_PART)

pbar.close()

# =========================
# Final save
# =========================
df = pd.DataFrame(rows)
df = df.sort_values(["image_name", "gsd_m_per_px"]).reset_index(drop=True)

print(df.head())
print("Done. Rows:", len(df))

df.to_csv(OUT_CSV, index=False)
df.to_excel(OUT_XLSX, index=False)

print("Saved FINAL:")
print("CSV :", OUT_CSV)
print("XLSX:", OUT_XLSX)
# Out:
# Processing TRAIN (image x GSD):   0%|          | 0/1071 [00:21<?, ?it/s]
#
# Processing TRAIN (image x GSD):   0%|          | 1/1071 [00:30<9:01:16, 30.35s/it]
# Processing TRAIN (image x GSD):   0%|          | 2/1071 [00:38<5:10:30, 17.43s/it]
# Processing TRAIN (image x GSD):   0%|          | 3/1071 [00:51<4:36:00, 15.51s/it]
# Processing TRAIN (image x GSD):   0%|          | 4/1071 [01:00<3:44:10, 12.61s/it]
# Processing TRAIN (image x GSD):   0%|          | 5/1071 [01:05<2:56:12,  9.92s/it]
# Processing TRAIN (image x GSD):   1%|          | 6/1071 [01:10<2:29:55,  8.45s/it]
# Processing TRAIN (image x GSD):   1%|          | 7/1071 [01:15<2:05:07,  7.06s/it]
# Processing TRAIN (image x GSD):   1%|          | 8/1071 [01:42<4:01:08, 13.61s/it]
# Processing TRAIN (image x GSD):   1%|          | 9/1071 [01:50<3:30:02, 11.87s/it]
# Processing TRAIN (image x GSD):   1%|          | 10/1071 [02:03<3:36:05, 12.22s/it]
# Processing TRAIN (image x GSD):   1%|          | 11/1071 [02:11<3:13:10, 10.93s/it]
# Processing TRAIN (image x GSD):   1%|          | 12/1071 [02:17<2:43:40,  9.27s/it]
# Processing TRAIN (image x GSD):   1%|          | 13/1071 [02:22<2:23:35,  8.14s/it]
# Processing TRAIN (image x GSD):   1%|▏         | 14/1071 [02:27<2:05:57,  7.15s/it]
# Processing TRAIN (image x GSD):   1%|▏         | 15/1071 [02:55<3:56:23, 13.43s/it]
# Processing TRAIN (image x GSD):   1%|▏         | 16/1071 [03:22<5:07:04, 17.46s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 17/1071 [03:35<4:42:25, 16.08s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 18/1071 [03:43<3:59:34, 13.65s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 19/1071 [03:48<3:16:19, 11.20s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 20/1071 [03:54<2:46:16,  9.49s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 21/1071 [03:58<2:18:42,  7.93s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 22/1071 [04:26<4:05:11, 14.02s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 23/1071 [04:34<3:33:22, 12.22s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 24/1071 [04:47<3:37:58, 12.49s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 25/1071 [04:56<3:16:12, 11.25s/it]
# Processing TRAIN (image x GSD):   2%|▏         | 26/1071 [05:01<2:44:18,  9.43s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 27/1071 [05:07<2:24:36,  8.31s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 28/1071 [05:11<2:03:08,  7.08s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 29/1071 [05:39<3:50:37, 13.28s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 30/1071 [06:06<5:01:48, 17.40s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 31/1071 [06:19<4:38:57, 16.09s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 32/1071 [06:27<3:58:17, 13.76s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 33/1071 [06:32<3:13:43, 11.20s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 34/1071 [06:38<2:44:53,  9.54s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 35/1071 [06:42<2:17:07,  7.94s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 36/1071 [07:10<3:59:38, 13.89s/it]
# Processing TRAIN (image x GSD):   3%|▎         | 37/1071 [07:18<3:29:09, 12.14s/it]
# Processing TRAIN (image x GSD):   4%|▎         | 38/1071 [07:31<3:33:38, 12.41s/it]
# Processing TRAIN (image x GSD):   4%|▎         | 39/1071 [07:39<3:11:08, 11.11s/it]
# Processing TRAIN (image x GSD):   4%|▎         | 40/1071 [07:44<2:41:30,  9.40s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 41/1071 [07:50<2:21:30,  8.24s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 42/1071 [07:54<2:01:52,  7.11s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 43/1071 [08:22<3:48:12, 13.32s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 44/1071 [08:30<3:21:31, 11.77s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 45/1071 [08:44<3:28:10, 12.17s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 46/1071 [08:52<3:07:37, 10.98s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 47/1071 [08:57<2:37:59,  9.26s/it]
# Processing TRAIN (image x GSD):   4%|▍         | 48/1071 [09:03<2:19:13,  8.17s/it]
# Processing TRAIN (image x GSD):   5%|▍         | 49/1071 [09:07<1:58:52,  6.98s/it]
# Processing TRAIN (image x GSD):   5%|▍         | 50/1071 [09:35<3:45:32, 13.25s/it]
# Processing TRAIN (image x GSD):   5%|▍         | 51/1071 [10:02<4:55:50, 17.40s/it]
# Processing TRAIN (image x GSD):   5%|▍         | 52/1071 [10:15<4:32:41, 16.06s/it]
# Processing TRAIN (image x GSD):   5%|▍         | 53/1071 [10:23<3:52:19, 13.69s/it]
# Processing TRAIN (image x GSD):   5%|▌         | 54/1071 [10:28<3:08:57, 11.15s/it]
# Processing TRAIN (image x GSD):   5%|▌         | 55/1071 [10:34<2:40:41,  9.49s/it]
# Processing TRAIN (image x GSD):   5%|▌         | 56/1071 [10:38<2:13:42,  7.90s/it]
# Processing TRAIN (image x GSD):   5%|▌         | 57/1071 [11:06<3:54:21, 13.87s/it]
# Processing TRAIN (image x GSD):   5%|▌         | 58/1071 [11:33<5:00:53, 17.82s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 59/1071 [11:46<4:35:58, 16.36s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 60/1071 [11:54<3:54:25, 13.91s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 61/1071 [11:59<3:10:12, 11.30s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 62/1071 [12:05<2:41:14,  9.59s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 63/1071 [12:09<2:13:59,  7.98s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 64/1071 [12:37<3:53:30, 13.91s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 65/1071 [12:45<3:23:57, 12.16s/it]
# Processing TRAIN (image x GSD):   6%|▌         | 66/1071 [12:58<3:27:30, 12.39s/it]
# Processing TRAIN (image x GSD):   6%|▋         | 67/1071 [13:06<3:05:29, 11.09s/it]
# Processing TRAIN (image x GSD):   6%|▋         | 68/1071 [13:11<2:35:34,  9.31s/it]
# Processing TRAIN (image x GSD):   6%|▋         | 69/1071 [13:16<2:16:41,  8.19s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 70/1071 [13:21<1:57:29,  7.04s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 71/1071 [13:49<3:41:09, 13.27s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 72/1071 [14:16<4:50:16, 17.43s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 73/1071 [14:29<4:27:05, 16.06s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 74/1071 [14:37<3:47:07, 13.67s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 75/1071 [14:42<3:04:41, 11.13s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 76/1071 [14:48<2:36:59,  9.47s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 77/1071 [14:52<2:11:35,  7.94s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 78/1071 [15:20<3:50:23, 13.92s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 79/1071 [15:28<3:21:54, 12.21s/it]
# Processing TRAIN (image x GSD):   7%|▋         | 80/1071 [15:41<3:25:50, 12.46s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 81/1071 [15:49<3:04:32, 11.18s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 82/1071 [15:55<2:35:05,  9.41s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 83/1071 [16:00<2:15:51,  8.25s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 84/1071 [16:04<1:55:49,  7.04s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 85/1071 [16:32<3:39:23, 13.35s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 86/1071 [16:40<3:13:22, 11.78s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 87/1071 [16:54<3:19:23, 12.16s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 88/1071 [17:02<2:59:15, 10.94s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 89/1071 [17:07<2:30:52,  9.22s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 90/1071 [17:12<2:13:16,  8.15s/it]
# Processing TRAIN (image x GSD):   8%|▊         | 91/1071 [17:17<1:54:38,  7.02s/it]
# Processing TRAIN (image x GSD):   9%|▊         | 92/1071 [17:45<3:36:37, 13.28s/it]
# Processing TRAIN (image x GSD):   9%|▊         | 93/1071 [18:12<4:43:29, 17.39s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 94/1071 [18:25<4:21:06, 16.03s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 95/1071 [18:33<3:42:20, 13.67s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 96/1071 [18:41<3:16:09, 12.07s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 97/1071 [18:47<2:44:37, 10.14s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 98/1071 [18:51<2:15:39,  8.37s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 99/1071 [19:19<3:49:56, 14.19s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 100/1071 [19:27<3:19:47, 12.35s/it]
# Processing TRAIN (image x GSD):   9%|▉         | 101/1071 [19:40<3:22:14, 12.51s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 102/1071 [19:48<3:00:22, 11.17s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 103/1071 [19:53<2:32:11,  9.43s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 104/1071 [19:59<2:13:16,  8.27s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 105/1071 [20:04<1:56:48,  7.25s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 106/1071 [20:31<3:36:25, 13.46s/it]
# Processing TRAIN (image x GSD):  10%|▉         | 107/1071 [20:40<3:10:41, 11.87s/it]
# Processing TRAIN (image x GSD):  10%|█         | 108/1071 [20:53<3:15:57, 12.21s/it]
# Processing TRAIN (image x GSD):  10%|█         | 109/1071 [21:01<2:56:13, 10.99s/it]
# Processing TRAIN (image x GSD):  10%|█         | 110/1071 [21:06<2:28:20,  9.26s/it]
# Processing TRAIN (image x GSD):  10%|█         | 111/1071 [21:12<2:10:44,  8.17s/it]
# Processing TRAIN (image x GSD):  10%|█         | 112/1071 [21:16<1:51:38,  6.98s/it]
# Processing TRAIN (image x GSD):  11%|█         | 113/1071 [21:44<3:31:33, 13.25s/it]
# Processing TRAIN (image x GSD):  11%|█         | 114/1071 [21:52<3:06:50, 11.71s/it]
# Processing TRAIN (image x GSD):  11%|█         | 115/1071 [22:05<3:13:00, 12.11s/it]
# Processing TRAIN (image x GSD):  11%|█         | 116/1071 [22:13<2:53:35, 10.91s/it]
# Processing TRAIN (image x GSD):  11%|█         | 117/1071 [22:18<2:26:18,  9.20s/it]
# Processing TRAIN (image x GSD):  11%|█         | 118/1071 [22:24<2:08:40,  8.10s/it]
# Processing TRAIN (image x GSD):  11%|█         | 119/1071 [22:28<1:50:54,  6.99s/it]
# Processing TRAIN (image x GSD):  11%|█         | 120/1071 [22:56<3:29:57, 13.25s/it]
# Processing TRAIN (image x GSD):  11%|█▏        | 121/1071 [23:04<3:05:26, 11.71s/it]
# Processing TRAIN (image x GSD):  11%|█▏        | 122/1071 [23:17<3:11:28, 12.11s/it]
# Processing TRAIN (image x GSD):  11%|█▏        | 123/1071 [23:25<2:52:46, 10.94s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 124/1071 [23:31<2:25:45,  9.23s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 125/1071 [23:36<2:08:06,  8.12s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 126/1071 [23:40<1:49:32,  6.95s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 127/1071 [24:08<3:27:46, 13.21s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 128/1071 [24:16<3:03:32, 11.68s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 129/1071 [24:29<3:09:17, 12.06s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 130/1071 [24:37<2:50:06, 10.85s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 131/1071 [24:42<2:23:11,  9.14s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 132/1071 [24:48<2:06:06,  8.06s/it]
# Processing TRAIN (image x GSD):  12%|█▏        | 133/1071 [24:53<1:51:16,  7.12s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 134/1071 [25:21<3:27:45, 13.30s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 135/1071 [25:29<3:03:35, 11.77s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 136/1071 [25:42<3:08:53, 12.12s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 137/1071 [25:50<2:49:20, 10.88s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 138/1071 [25:55<2:23:13,  9.21s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 139/1071 [26:01<2:06:01,  8.11s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 140/1071 [26:05<1:47:41,  6.94s/it]
# [Checkpoint] Saved partial after 20 images:
# CSV : /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.csv
# XLSX: /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.xlsx
# Processing TRAIN (image x GSD):  13%|█▎        | 141/1071 [26:34<3:29:28, 13.51s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 142/1071 [26:42<3:03:18, 11.84s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 143/1071 [26:55<3:08:59, 12.22s/it]
# Processing TRAIN (image x GSD):  13%|█▎        | 144/1071 [27:03<2:49:38, 10.98s/it]
# Processing TRAIN (image x GSD):  14%|█▎        | 145/1071 [27:08<2:22:29,  9.23s/it]
# Processing TRAIN (image x GSD):  14%|█▎        | 146/1071 [27:14<2:05:46,  8.16s/it]
# Processing TRAIN (image x GSD):  14%|█▎        | 147/1071 [27:18<1:50:04,  7.15s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 148/1071 [27:46<3:25:17, 13.35s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 149/1071 [27:54<3:00:27, 11.74s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 150/1071 [28:07<3:05:38, 12.09s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 151/1071 [28:15<2:46:28, 10.86s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 152/1071 [28:21<2:21:33,  9.24s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 153/1071 [28:26<2:04:31,  8.14s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 154/1071 [28:30<1:46:31,  6.97s/it]
# Processing TRAIN (image x GSD):  14%|█▍        | 155/1071 [28:59<3:25:56, 13.49s/it]
# Processing TRAIN (image x GSD):  15%|█▍        | 156/1071 [29:07<3:00:09, 11.81s/it]
# Processing TRAIN (image x GSD):  15%|█▍        | 157/1071 [29:20<3:05:29, 12.18s/it]
# Processing TRAIN (image x GSD):  15%|█▍        | 158/1071 [29:28<2:47:09, 10.99s/it]
# Processing TRAIN (image x GSD):  15%|█▍        | 159/1071 [29:33<2:20:29,  9.24s/it]
# Processing TRAIN (image x GSD):  15%|█▍        | 160/1071 [29:39<2:03:59,  8.17s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 161/1071 [29:43<1:45:47,  6.98s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 162/1071 [30:11<3:20:49, 13.26s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 163/1071 [30:19<2:56:43, 11.68s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 164/1071 [30:32<3:02:19, 12.06s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 165/1071 [30:40<2:43:32, 10.83s/it]
# Processing TRAIN (image x GSD):  15%|█▌        | 166/1071 [30:45<2:18:23,  9.17s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 167/1071 [30:51<2:01:40,  8.08s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 168/1071 [30:55<1:45:08,  6.99s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 169/1071 [31:23<3:18:43, 13.22s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 170/1071 [31:31<2:55:54, 11.71s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 171/1071 [31:44<3:01:42, 12.11s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 172/1071 [31:52<2:43:39, 10.92s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 173/1071 [31:58<2:17:57,  9.22s/it]
# Processing TRAIN (image x GSD):  16%|█▌        | 174/1071 [32:03<2:01:25,  8.12s/it]
# Processing TRAIN (image x GSD):  16%|█▋        | 175/1071 [32:07<1:43:41,  6.94s/it]
# Processing TRAIN (image x GSD):  16%|█▋        | 176/1071 [32:35<3:17:48, 13.26s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 177/1071 [32:44<2:54:24, 11.70s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 178/1071 [32:57<3:00:07, 12.10s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 179/1071 [33:05<2:41:41, 10.88s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 180/1071 [33:10<2:16:11,  9.17s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 181/1071 [33:15<2:00:17,  8.11s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 182/1071 [33:20<1:45:12,  7.10s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 183/1071 [33:48<3:16:24, 13.27s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 184/1071 [34:15<4:15:59, 17.32s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 185/1071 [34:28<3:56:24, 16.01s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 186/1071 [34:36<3:21:38, 13.67s/it]
# Processing TRAIN (image x GSD):  17%|█▋        | 187/1071 [34:41<2:43:57, 11.13s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 188/1071 [34:47<2:19:32,  9.48s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 189/1071 [34:51<1:58:43,  8.08s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 190/1071 [35:19<3:26:29, 14.06s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 191/1071 [35:27<2:59:55, 12.27s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 192/1071 [35:40<3:03:00, 12.49s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 193/1071 [35:49<2:43:30, 11.17s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 194/1071 [35:54<2:17:52,  9.43s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 195/1071 [36:00<2:00:46,  8.27s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 196/1071 [36:04<1:44:00,  7.13s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 197/1071 [36:32<3:15:02, 13.39s/it]
# Processing TRAIN (image x GSD):  18%|█▊        | 198/1071 [36:40<2:52:11, 11.83s/it]
# Processing TRAIN (image x GSD):  19%|█▊        | 199/1071 [36:53<2:57:07, 12.19s/it]
# Processing TRAIN (image x GSD):  19%|█▊        | 200/1071 [37:01<2:38:39, 10.93s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 201/1071 [37:06<2:13:53,  9.23s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 202/1071 [37:12<1:57:42,  8.13s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 203/1071 [37:17<1:43:00,  7.12s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 204/1071 [37:46<3:17:56, 13.70s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 205/1071 [37:54<2:52:52, 11.98s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 206/1071 [38:07<2:57:36, 12.32s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 207/1071 [38:15<2:39:45, 11.09s/it]
# Processing TRAIN (image x GSD):  19%|█▉        | 208/1071 [38:20<2:14:07,  9.32s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 209/1071 [38:26<1:58:10,  8.23s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 210/1071 [38:30<1:40:45,  7.02s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 211/1071 [38:58<3:10:58, 13.32s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 212/1071 [39:06<2:47:46, 11.72s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 213/1071 [39:19<2:53:05, 12.10s/it]
# Processing TRAIN (image x GSD):  20%|█▉        | 214/1071 [39:27<2:35:23, 10.88s/it]
# Processing TRAIN (image x GSD):  20%|██        | 215/1071 [39:32<2:10:58,  9.18s/it]
# Processing TRAIN (image x GSD):  20%|██        | 216/1071 [39:38<1:55:12,  8.08s/it]
# Processing TRAIN (image x GSD):  20%|██        | 217/1071 [39:42<1:39:22,  6.98s/it]
# Processing TRAIN (image x GSD):  20%|██        | 218/1071 [40:10<3:08:52, 13.29s/it]
# Processing TRAIN (image x GSD):  20%|██        | 219/1071 [40:19<2:47:12, 11.77s/it]
# Processing TRAIN (image x GSD):  21%|██        | 220/1071 [40:32<2:52:22, 12.15s/it]
# Processing TRAIN (image x GSD):  21%|██        | 221/1071 [40:40<2:34:42, 10.92s/it]
# Processing TRAIN (image x GSD):  21%|██        | 222/1071 [40:45<2:10:50,  9.25s/it]
# Processing TRAIN (image x GSD):  21%|██        | 223/1071 [40:51<1:55:00,  8.14s/it]
# Processing TRAIN (image x GSD):  21%|██        | 224/1071 [40:55<1:38:28,  6.98s/it]
# Processing TRAIN (image x GSD):  21%|██        | 225/1071 [41:24<3:12:18, 13.64s/it]
# Processing TRAIN (image x GSD):  21%|██        | 226/1071 [41:32<2:48:12, 11.94s/it]
# Processing TRAIN (image x GSD):  21%|██        | 227/1071 [41:45<2:53:13, 12.31s/it]
# Processing TRAIN (image x GSD):  21%|██▏       | 228/1071 [41:53<2:35:50, 11.09s/it]
# Processing TRAIN (image x GSD):  21%|██▏       | 229/1071 [41:59<2:11:01,  9.34s/it]
# Processing TRAIN (image x GSD):  21%|██▏       | 230/1071 [42:04<1:55:34,  8.25s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 231/1071 [42:09<1:38:32,  7.04s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 232/1071 [42:37<3:06:46, 13.36s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 233/1071 [43:04<4:03:29, 17.43s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 234/1071 [43:17<3:44:35, 16.10s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 235/1071 [43:25<3:11:13, 13.72s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 236/1071 [43:30<2:35:39, 11.19s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 237/1071 [43:36<2:12:16,  9.52s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 238/1071 [43:40<1:50:02,  7.93s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 239/1071 [44:08<3:14:06, 14.00s/it]
# Processing TRAIN (image x GSD):  22%|██▏       | 240/1071 [44:35<4:08:45, 17.96s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 241/1071 [44:48<3:48:02, 16.49s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 242/1071 [44:56<3:12:51, 13.96s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 243/1071 [45:02<2:36:51, 11.37s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 244/1071 [45:07<2:12:37,  9.62s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 245/1071 [45:12<1:50:22,  8.02s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 246/1071 [45:41<3:18:27, 14.43s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 247/1071 [46:08<4:10:21, 18.23s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 248/1071 [46:21<3:48:25, 16.65s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 249/1071 [46:29<3:12:38, 14.06s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 250/1071 [46:35<2:37:30, 11.51s/it]
# Processing TRAIN (image x GSD):  23%|██▎       | 251/1071 [46:40<2:12:55,  9.73s/it]
# Processing TRAIN (image x GSD):  24%|██▎       | 252/1071 [46:44<1:50:35,  8.10s/it]
# Processing TRAIN (image x GSD):  24%|██▎       | 253/1071 [47:13<3:12:51, 14.15s/it]
# Processing TRAIN (image x GSD):  24%|██▎       | 254/1071 [47:40<4:06:09, 18.08s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 255/1071 [47:53<3:44:53, 16.54s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 256/1071 [48:01<3:10:17, 14.01s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 257/1071 [48:06<2:34:56, 11.42s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 258/1071 [48:12<2:10:57,  9.67s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 259/1071 [48:16<1:49:51,  8.12s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 260/1071 [48:45<3:11:34, 14.17s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 261/1071 [49:12<4:04:45, 18.13s/it]
# Processing TRAIN (image x GSD):  24%|██▍       | 262/1071 [49:25<3:43:12, 16.55s/it]
# Processing TRAIN (image x GSD):  25%|██▍       | 263/1071 [49:33<3:08:39, 14.01s/it]
# Processing TRAIN (image x GSD):  25%|██▍       | 264/1071 [49:41<2:45:34, 12.31s/it]
# Processing TRAIN (image x GSD):  25%|██▍       | 265/1071 [49:47<2:18:42, 10.33s/it]
# Processing TRAIN (image x GSD):  25%|██▍       | 266/1071 [49:51<1:54:00,  8.50s/it]
# Processing TRAIN (image x GSD):  25%|██▍       | 267/1071 [50:19<3:12:15, 14.35s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 268/1071 [50:46<4:03:01, 18.16s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 269/1071 [50:59<3:41:44, 16.59s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 270/1071 [51:08<3:07:46, 14.07s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 271/1071 [51:13<2:32:22, 11.43s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 272/1071 [51:18<2:09:04,  9.69s/it]
# Processing TRAIN (image x GSD):  25%|██▌       | 273/1071 [51:23<1:47:08,  8.06s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 274/1071 [51:51<3:08:19, 14.18s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 275/1071 [51:59<2:43:51, 12.35s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 276/1071 [52:12<2:46:00, 12.53s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 277/1071 [52:20<2:28:12, 11.20s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 278/1071 [52:25<2:04:15,  9.40s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 279/1071 [52:31<1:48:59,  8.26s/it]
# Processing TRAIN (image x GSD):  26%|██▌       | 280/1071 [52:35<1:33:22,  7.08s/it]
# [Checkpoint] Saved partial after 40 images:
# CSV : /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.csv
# XLSX: /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.xlsx
# Processing TRAIN (image x GSD):  26%|██▌       | 281/1071 [53:04<2:57:05, 13.45s/it]
# Processing TRAIN (image x GSD):  26%|██▋       | 282/1071 [53:31<3:50:15, 17.51s/it]
# Processing TRAIN (image x GSD):  26%|██▋       | 283/1071 [53:44<3:32:07, 16.15s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 284/1071 [53:52<3:00:17, 13.75s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 285/1071 [53:57<2:27:02, 11.22s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 286/1071 [54:03<2:05:00,  9.56s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 287/1071 [54:07<1:44:01,  7.96s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 288/1071 [54:35<3:03:51, 14.09s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 289/1071 [55:03<3:54:28, 17.99s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 290/1071 [55:16<3:35:01, 16.52s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 291/1071 [55:24<3:02:19, 14.02s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 292/1071 [55:32<2:40:24, 12.35s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 293/1071 [55:38<2:13:42, 10.31s/it]
# Processing TRAIN (image x GSD):  27%|██▋       | 294/1071 [55:42<1:49:57,  8.49s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 295/1071 [56:11<3:10:28, 14.73s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 296/1071 [56:38<3:58:20, 18.45s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 297/1071 [56:51<3:36:30, 16.78s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 298/1071 [56:59<3:02:13, 14.14s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 299/1071 [57:08<2:40:37, 12.48s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 300/1071 [57:14<2:13:49, 10.41s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 301/1071 [57:18<1:50:30,  8.61s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 302/1071 [57:46<3:05:42, 14.49s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 303/1071 [58:13<3:54:15, 18.30s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 304/1071 [58:26<3:33:20, 16.69s/it]
# Processing TRAIN (image x GSD):  28%|██▊       | 305/1071 [58:34<3:00:03, 14.10s/it]
# Processing TRAIN (image x GSD):  29%|██▊       | 306/1071 [58:43<2:37:57, 12.39s/it]
# Processing TRAIN (image x GSD):  29%|██▊       | 307/1071 [58:48<2:12:17, 10.39s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 308/1071 [58:53<1:48:42,  8.55s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 309/1071 [59:21<3:03:10, 14.42s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 310/1071 [59:48<3:50:41, 18.19s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 311/1071 [1:00:01<3:30:22, 16.61s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 312/1071 [1:00:09<2:58:06, 14.08s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 313/1071 [1:00:17<2:36:24, 12.38s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 314/1071 [1:00:23<2:10:15, 10.32s/it]
# Processing TRAIN (image x GSD):  29%|██▉       | 315/1071 [1:00:27<1:47:12,  8.51s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 316/1071 [1:00:56<3:04:03, 14.63s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 317/1071 [1:01:23<3:50:32, 18.34s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 318/1071 [1:01:36<3:29:38, 16.70s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 319/1071 [1:01:44<2:56:40, 14.10s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 320/1071 [1:01:53<2:35:45, 12.44s/it]
# Processing TRAIN (image x GSD):  30%|██▉       | 321/1071 [1:01:58<2:09:54, 10.39s/it]
# Processing TRAIN (image x GSD):  30%|███       | 322/1071 [1:02:02<1:46:48,  8.56s/it]
# Processing TRAIN (image x GSD):  30%|███       | 323/1071 [1:02:31<2:59:43, 14.42s/it]
# Processing TRAIN (image x GSD):  30%|███       | 324/1071 [1:02:58<3:46:46, 18.22s/it]
# Processing TRAIN (image x GSD):  30%|███       | 325/1071 [1:03:11<3:27:11, 16.66s/it]
# Processing TRAIN (image x GSD):  30%|███       | 326/1071 [1:03:19<2:55:31, 14.14s/it]
# Processing TRAIN (image x GSD):  31%|███       | 327/1071 [1:03:27<2:33:51, 12.41s/it]
# Processing TRAIN (image x GSD):  31%|███       | 328/1071 [1:03:33<2:08:20, 10.36s/it]
# Processing TRAIN (image x GSD):  31%|███       | 329/1071 [1:03:37<1:45:16,  8.51s/it]
# Processing TRAIN (image x GSD):  31%|███       | 330/1071 [1:04:05<2:57:28, 14.37s/it]
# Processing TRAIN (image x GSD):  31%|███       | 331/1071 [1:04:32<3:44:21, 18.19s/it]
# Processing TRAIN (image x GSD):  31%|███       | 332/1071 [1:04:45<3:24:45, 16.62s/it]
# Processing TRAIN (image x GSD):  31%|███       | 333/1071 [1:04:53<2:52:39, 14.04s/it]
# Processing TRAIN (image x GSD):  31%|███       | 334/1071 [1:05:02<2:32:06, 12.38s/it]
# Processing TRAIN (image x GSD):  31%|███▏      | 335/1071 [1:05:07<2:06:46, 10.33s/it]
# Processing TRAIN (image x GSD):  31%|███▏      | 336/1071 [1:05:12<1:44:34,  8.54s/it]
# Processing TRAIN (image x GSD):  31%|███▏      | 337/1071 [1:05:40<2:55:46, 14.37s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 338/1071 [1:06:07<3:42:56, 18.25s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 339/1071 [1:06:20<3:23:17, 16.66s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 340/1071 [1:06:28<2:51:35, 14.08s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 341/1071 [1:06:36<2:30:31, 12.37s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 342/1071 [1:06:42<2:05:57, 10.37s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 343/1071 [1:06:46<1:43:29,  8.53s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 344/1071 [1:07:14<2:54:30, 14.40s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 345/1071 [1:07:22<2:31:02, 12.48s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 346/1071 [1:07:35<2:32:38, 12.63s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 347/1071 [1:07:43<2:15:45, 11.25s/it]
# Processing TRAIN (image x GSD):  32%|███▏      | 348/1071 [1:07:49<1:54:11,  9.48s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 349/1071 [1:07:54<1:39:54,  8.30s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 350/1071 [1:07:59<1:25:31,  7.12s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 351/1071 [1:08:27<2:41:12, 13.43s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 352/1071 [1:08:54<3:30:50, 17.59s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 353/1071 [1:09:07<3:13:35, 16.18s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 354/1071 [1:09:15<2:44:15, 13.75s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 355/1071 [1:09:23<2:24:48, 12.14s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 356/1071 [1:09:29<2:01:27, 10.19s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 357/1071 [1:09:33<1:40:05,  8.41s/it]
# Processing TRAIN (image x GSD):  33%|███▎      | 358/1071 [1:10:01<2:49:56, 14.30s/it]
# Processing TRAIN (image x GSD):  34%|███▎      | 359/1071 [1:10:28<3:35:08, 18.13s/it]
# Processing TRAIN (image x GSD):  34%|███▎      | 360/1071 [1:10:41<3:16:41, 16.60s/it]
# Processing TRAIN (image x GSD):  34%|███▎      | 361/1071 [1:10:50<2:47:08, 14.12s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 362/1071 [1:10:58<2:26:40, 12.41s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 363/1071 [1:11:04<2:02:12, 10.36s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 364/1071 [1:11:08<1:40:27,  8.53s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 365/1071 [1:11:37<2:53:03, 14.71s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 366/1071 [1:12:04<3:36:02, 18.39s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 367/1071 [1:12:17<3:16:22, 16.74s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 368/1071 [1:12:25<2:45:26, 14.12s/it]
# Processing TRAIN (image x GSD):  34%|███▍      | 369/1071 [1:12:34<2:25:42, 12.45s/it]
# Processing TRAIN (image x GSD):  35%|███▍      | 370/1071 [1:12:39<2:01:32, 10.40s/it]
# Processing TRAIN (image x GSD):  35%|███▍      | 371/1071 [1:12:44<1:40:12,  8.59s/it]
# Processing TRAIN (image x GSD):  35%|███▍      | 372/1071 [1:13:11<2:47:43, 14.40s/it]
# Processing TRAIN (image x GSD):  35%|███▍      | 373/1071 [1:13:38<3:31:12, 18.16s/it]
# Processing TRAIN (image x GSD):  35%|███▍      | 374/1071 [1:13:51<3:12:56, 16.61s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 375/1071 [1:14:00<2:43:06, 14.06s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 376/1071 [1:14:08<2:22:59, 12.34s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 377/1071 [1:14:13<1:59:27, 10.33s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 378/1071 [1:14:18<1:38:04,  8.49s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 379/1071 [1:14:46<2:45:37, 14.36s/it]
# Processing TRAIN (image x GSD):  35%|███▌      | 380/1071 [1:14:54<2:23:41, 12.48s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 381/1071 [1:15:07<2:25:25, 12.64s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 382/1071 [1:15:15<2:09:23, 11.27s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 383/1071 [1:15:20<1:48:26,  9.46s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 384/1071 [1:15:26<1:34:56,  8.29s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 385/1071 [1:15:30<1:21:22,  7.12s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 386/1071 [1:15:58<2:32:59, 13.40s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 387/1071 [1:16:06<2:14:20, 11.78s/it]
# Processing TRAIN (image x GSD):  36%|███▌      | 388/1071 [1:16:19<2:18:02, 12.13s/it]
# Processing TRAIN (image x GSD):  36%|███▋      | 389/1071 [1:16:27<2:03:39, 10.88s/it]
# Processing TRAIN (image x GSD):  36%|███▋      | 390/1071 [1:16:32<1:44:41,  9.22s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 391/1071 [1:16:38<1:32:05,  8.13s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 392/1071 [1:16:42<1:18:46,  6.96s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 393/1071 [1:17:11<2:33:00, 13.54s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 394/1071 [1:17:19<2:13:57, 11.87s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 395/1071 [1:17:32<2:17:42, 12.22s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 396/1071 [1:17:40<2:04:14, 11.04s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 397/1071 [1:17:46<1:44:27,  9.30s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 398/1071 [1:17:51<1:32:03,  8.21s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 399/1071 [1:17:56<1:18:35,  7.02s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 400/1071 [1:18:24<2:29:24, 13.36s/it]
# Processing TRAIN (image x GSD):  37%|███▋      | 401/1071 [1:18:32<2:11:33, 11.78s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 402/1071 [1:18:45<2:15:27, 12.15s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 403/1071 [1:18:53<2:01:38, 10.93s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 404/1071 [1:18:58<1:42:29,  9.22s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 405/1071 [1:19:04<1:30:15,  8.13s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 406/1071 [1:19:08<1:17:40,  7.01s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 407/1071 [1:19:36<2:27:48, 13.36s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 408/1071 [1:19:44<2:09:55, 11.76s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 409/1071 [1:19:57<2:13:56, 12.14s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 410/1071 [1:20:05<1:59:54, 10.88s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 411/1071 [1:20:11<1:41:36,  9.24s/it]
# Processing TRAIN (image x GSD):  38%|███▊      | 412/1071 [1:20:16<1:29:19,  8.13s/it]
# Processing TRAIN (image x GSD):  39%|███▊      | 413/1071 [1:20:20<1:16:18,  6.96s/it]
# Processing TRAIN (image x GSD):  39%|███▊      | 414/1071 [1:20:49<2:27:41, 13.49s/it]
# Processing TRAIN (image x GSD):  39%|███▊      | 415/1071 [1:21:02<2:26:31, 13.40s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 416/1071 [1:21:18<2:32:24, 13.96s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 417/1071 [1:21:27<2:17:24, 12.61s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 418/1071 [1:21:29<1:43:22,  9.50s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 419/1071 [1:21:30<1:15:55,  6.99s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 420/1071 [1:21:32<57:12,  5.27s/it]
# [Checkpoint] Saved partial after 60 images:
# CSV : /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.csv
# XLSX: /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.xlsx
# Processing TRAIN (image x GSD):  39%|███▉      | 421/1071 [1:22:00<2:12:42, 12.25s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 422/1071 [1:22:08<1:58:47, 10.98s/it]
# Processing TRAIN (image x GSD):  39%|███▉      | 423/1071 [1:22:21<2:04:43, 11.55s/it]
# Processing TRAIN (image x GSD):  40%|███▉      | 424/1071 [1:22:29<1:52:58, 10.48s/it]
# Processing TRAIN (image x GSD):  40%|███▉      | 425/1071 [1:22:34<1:36:10,  8.93s/it]
# Processing TRAIN (image x GSD):  40%|███▉      | 426/1071 [1:22:40<1:25:04,  7.91s/it]
# Processing TRAIN (image x GSD):  40%|███▉      | 427/1071 [1:22:45<1:15:32,  7.04s/it]
# Processing TRAIN (image x GSD):  40%|███▉      | 428/1071 [1:23:13<2:22:56, 13.34s/it]
# Processing TRAIN (image x GSD):  40%|████      | 429/1071 [1:23:21<2:06:11, 11.79s/it]
# Processing TRAIN (image x GSD):  40%|████      | 430/1071 [1:23:34<2:09:51, 12.16s/it]
# Processing TRAIN (image x GSD):  40%|████      | 431/1071 [1:23:42<1:56:19, 10.91s/it]
# Processing TRAIN (image x GSD):  40%|████      | 432/1071 [1:23:48<1:38:11,  9.22s/it]
# Processing TRAIN (image x GSD):  40%|████      | 433/1071 [1:23:53<1:26:25,  8.13s/it]
# Processing TRAIN (image x GSD):  41%|████      | 434/1071 [1:23:57<1:13:51,  6.96s/it]
# Processing TRAIN (image x GSD):  41%|████      | 435/1071 [1:24:27<2:24:29, 13.63s/it]
# Processing TRAIN (image x GSD):  41%|████      | 436/1071 [1:24:34<2:06:03, 11.91s/it]
# Processing TRAIN (image x GSD):  41%|████      | 437/1071 [1:24:47<2:09:23, 12.25s/it]
# Processing TRAIN (image x GSD):  41%|████      | 438/1071 [1:24:56<1:56:20, 11.03s/it]
# Processing TRAIN (image x GSD):  41%|████      | 439/1071 [1:25:01<1:37:44,  9.28s/it]
# Processing TRAIN (image x GSD):  41%|████      | 440/1071 [1:25:07<1:26:09,  8.19s/it]
# Processing TRAIN (image x GSD):  41%|████      | 441/1071 [1:25:11<1:13:27,  7.00s/it]
# Processing TRAIN (image x GSD):  41%|████▏     | 442/1071 [1:25:39<2:19:19, 13.29s/it]
# Processing TRAIN (image x GSD):  41%|████▏     | 443/1071 [1:25:47<2:02:16, 11.68s/it]
# Processing TRAIN (image x GSD):  41%|████▏     | 444/1071 [1:26:00<2:05:52, 12.05s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 445/1071 [1:26:09<1:57:46, 11.29s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 446/1071 [1:26:15<1:41:40,  9.76s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 447/1071 [1:26:21<1:30:14,  8.68s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 448/1071 [1:26:23<1:06:59,  6.45s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 449/1071 [1:26:51<2:14:34, 12.98s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 450/1071 [1:26:59<1:59:17, 11.53s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 451/1071 [1:27:12<2:03:36, 11.96s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 452/1071 [1:27:22<1:56:13, 11.27s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 453/1071 [1:27:28<1:40:43,  9.78s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 454/1071 [1:27:29<1:13:50,  7.18s/it]
# Processing TRAIN (image x GSD):  42%|████▏     | 455/1071 [1:27:30<55:27,  5.40s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 456/1071 [1:27:59<2:05:39, 12.26s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 457/1071 [1:28:07<1:52:28, 10.99s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 458/1071 [1:28:19<1:58:12, 11.57s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 459/1071 [1:28:27<1:46:52, 10.48s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 460/1071 [1:28:33<1:31:18,  8.97s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 461/1071 [1:28:39<1:22:24,  8.11s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 462/1071 [1:28:40<1:01:28,  6.06s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 463/1071 [1:29:10<2:11:59, 13.03s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 464/1071 [1:29:17<1:56:20, 11.50s/it]
# Processing TRAIN (image x GSD):  43%|████▎     | 465/1071 [1:29:30<2:00:47, 11.96s/it]
# Processing TRAIN (image x GSD):  44%|████▎     | 466/1071 [1:29:39<1:49:11, 10.83s/it]
# Processing TRAIN (image x GSD):  44%|████▎     | 467/1071 [1:29:44<1:31:57,  9.13s/it]
# Processing TRAIN (image x GSD):  44%|████▎     | 468/1071 [1:29:50<1:21:16,  8.09s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 469/1071 [1:29:54<1:09:30,  6.93s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 470/1071 [1:30:22<2:12:33, 13.23s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 471/1071 [1:30:30<1:56:28, 11.65s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 472/1071 [1:30:42<1:59:54, 12.01s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 473/1071 [1:30:51<1:47:44, 10.81s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 474/1071 [1:30:59<1:40:32, 10.10s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 475/1071 [1:31:05<1:27:11,  8.78s/it]
# Processing TRAIN (image x GSD):  44%|████▍     | 476/1071 [1:31:09<1:13:30,  7.41s/it]
# Processing TRAIN (image x GSD):  45%|████▍     | 477/1071 [1:31:37<2:15:27, 13.68s/it]
# Processing TRAIN (image x GSD):  45%|████▍     | 478/1071 [1:32:04<2:55:03, 17.71s/it]
# Processing TRAIN (image x GSD):  45%|████▍     | 479/1071 [1:32:17<2:41:04, 16.32s/it]
# Processing TRAIN (image x GSD):  45%|████▍     | 480/1071 [1:32:26<2:16:48, 13.89s/it]
# Processing TRAIN (image x GSD):  45%|████▍     | 481/1071 [1:32:31<1:50:54, 11.28s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 482/1071 [1:32:37<1:34:22,  9.61s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 483/1071 [1:32:41<1:18:24,  8.00s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 484/1071 [1:33:09<2:17:06, 14.01s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 485/1071 [1:33:17<1:59:15, 12.21s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 486/1071 [1:33:30<2:01:23, 12.45s/it]
# Processing TRAIN (image x GSD):  45%|████▌     | 487/1071 [1:33:38<1:48:21, 11.13s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 488/1071 [1:33:43<1:30:57,  9.36s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 489/1071 [1:33:49<1:19:41,  8.22s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 490/1071 [1:33:53<1:08:30,  7.08s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 491/1071 [1:34:21<2:08:56, 13.34s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 492/1071 [1:34:29<1:53:40, 11.78s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 493/1071 [1:34:42<1:56:29, 12.09s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 494/1071 [1:34:50<1:44:17, 10.85s/it]
# Processing TRAIN (image x GSD):  46%|████▌     | 495/1071 [1:34:55<1:27:59,  9.17s/it]
# Processing TRAIN (image x GSD):  46%|████▋     | 496/1071 [1:35:01<1:17:19,  8.07s/it]
# Processing TRAIN (image x GSD):  46%|████▋     | 497/1071 [1:35:02<57:38,  6.03s/it]
# Processing TRAIN (image x GSD):  46%|████▋     | 498/1071 [1:35:30<2:01:16, 12.70s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 499/1071 [1:35:38<1:47:44, 11.30s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 500/1071 [1:35:51<1:52:08, 11.78s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 501/1071 [1:36:01<1:45:35, 11.12s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 502/1071 [1:36:07<1:31:23,  9.64s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 503/1071 [1:36:08<1:07:01,  7.08s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 504/1071 [1:36:09<50:27,  5.34s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 505/1071 [1:36:38<1:57:03, 12.41s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 506/1071 [1:36:46<1:43:53, 11.03s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 507/1071 [1:36:59<1:49:15, 11.62s/it]
# Processing TRAIN (image x GSD):  47%|████▋     | 508/1071 [1:37:08<1:42:59, 10.98s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 509/1071 [1:37:15<1:29:29,  9.55s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 510/1071 [1:37:16<1:05:44,  7.03s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 511/1071 [1:37:17<49:26,  5.30s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 512/1071 [1:37:45<1:52:49, 12.11s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 513/1071 [1:37:53<1:41:24, 10.90s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 514/1071 [1:38:06<1:46:53, 11.51s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 515/1071 [1:38:14<1:37:23, 10.51s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 516/1071 [1:38:20<1:22:31,  8.92s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 517/1071 [1:38:25<1:13:00,  7.91s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 518/1071 [1:38:29<1:02:45,  6.81s/it]
# Processing TRAIN (image x GSD):  48%|████▊     | 519/1071 [1:38:58<2:01:49, 13.24s/it]
# Processing TRAIN (image x GSD):  49%|████▊     | 520/1071 [1:39:06<1:47:11, 11.67s/it]
# Processing TRAIN (image x GSD):  49%|████▊     | 521/1071 [1:39:19<1:50:37, 12.07s/it]
# Processing TRAIN (image x GSD):  49%|████▊     | 522/1071 [1:39:26<1:39:02, 10.82s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 523/1071 [1:39:35<1:31:51, 10.06s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 524/1071 [1:39:40<1:19:35,  8.73s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 525/1071 [1:39:45<1:07:06,  7.37s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 526/1071 [1:40:13<2:03:18, 13.58s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 527/1071 [1:40:21<1:48:04, 11.92s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 528/1071 [1:40:34<1:50:30, 12.21s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 529/1071 [1:40:42<1:38:57, 10.95s/it]
# Processing TRAIN (image x GSD):  49%|████▉     | 530/1071 [1:40:50<1:31:36, 10.16s/it]
# Processing TRAIN (image x GSD):  50%|████▉     | 531/1071 [1:40:56<1:19:21,  8.82s/it]
# Processing TRAIN (image x GSD):  50%|████▉     | 532/1071 [1:41:00<1:06:50,  7.44s/it]
# Processing TRAIN (image x GSD):  50%|████▉     | 533/1071 [1:41:28<2:02:06, 13.62s/it]
# Processing TRAIN (image x GSD):  50%|████▉     | 534/1071 [1:41:55<2:37:24, 17.59s/it]
# Processing TRAIN (image x GSD):  50%|████▉     | 535/1071 [1:42:08<2:24:21, 16.16s/it]
# Processing TRAIN (image x GSD):  50%|█████     | 536/1071 [1:42:16<2:02:41, 13.76s/it]
# Processing TRAIN (image x GSD):  50%|█████     | 537/1071 [1:42:24<1:48:07, 12.15s/it]
# Processing TRAIN (image x GSD):  50%|█████     | 538/1071 [1:42:30<1:30:15, 10.16s/it]
# Processing TRAIN (image x GSD):  50%|█████     | 539/1071 [1:42:34<1:14:15,  8.38s/it]
# Processing TRAIN (image x GSD):  50%|█████     | 540/1071 [1:43:03<2:09:18, 14.61s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 541/1071 [1:43:11<1:51:25, 12.61s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 542/1071 [1:43:24<1:52:39, 12.78s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 543/1071 [1:43:32<1:40:24, 11.41s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 544/1071 [1:43:41<1:32:10, 10.50s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 545/1071 [1:43:46<1:18:56,  9.00s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 546/1071 [1:43:50<1:06:16,  7.57s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 547/1071 [1:44:19<2:01:45, 13.94s/it]
# Processing TRAIN (image x GSD):  51%|█████     | 548/1071 [1:44:27<1:45:38, 12.12s/it]
# Processing TRAIN (image x GSD):  51%|█████▏    | 549/1071 [1:44:40<1:47:48, 12.39s/it]
# Processing TRAIN (image x GSD):  51%|█████▏    | 550/1071 [1:44:48<1:36:20, 11.09s/it]
# Processing TRAIN (image x GSD):  51%|█████▏    | 551/1071 [1:44:53<1:20:44,  9.32s/it]
# ...
# Processing TRAIN (image x GSD):  85%|████████▌ | 912/1071 [2:56:46<48:39, 18.36s/it]
# Processing TRAIN (image x GSD):  85%|████████▌ | 913/1071 [2:56:59<44:03, 16.73s/it]
# Processing TRAIN (image x GSD):  85%|████████▌ | 914/1071 [2:57:07<36:55, 14.11s/it]
# Processing TRAIN (image x GSD):  85%|████████▌ | 915/1071 [2:57:15<32:19, 12.44s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 916/1071 [2:57:21<26:46, 10.37s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 917/1071 [2:57:25<22:03,  8.60s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 918/1071 [2:57:54<36:48, 14.43s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 919/1071 [2:58:21<46:08, 18.21s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 920/1071 [2:58:33<41:43, 16.58s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 921/1071 [2:58:41<35:02, 14.02s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 922/1071 [2:58:50<30:35, 12.32s/it]
# Processing TRAIN (image x GSD):  86%|████████▌ | 923/1071 [2:58:55<25:27, 10.32s/it]
# Processing TRAIN (image x GSD):  86%|████████▋ | 924/1071 [2:59:00<21:12,  8.66s/it]
# Processing TRAIN (image x GSD):  86%|████████▋ | 925/1071 [2:59:28<35:18, 14.51s/it]
# Processing TRAIN (image x GSD):  86%|████████▋ | 926/1071 [2:59:55<44:08, 18.26s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 927/1071 [3:00:08<40:00, 16.67s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 928/1071 [3:00:17<33:43, 14.15s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 929/1071 [3:00:25<29:25, 12.43s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 930/1071 [3:00:31<24:22, 10.37s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 931/1071 [3:00:35<19:53,  8.53s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 932/1071 [3:01:04<34:09, 14.74s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 933/1071 [3:01:31<42:23, 18.43s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 934/1071 [3:01:44<38:18, 16.78s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 935/1071 [3:01:52<32:04, 14.15s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 936/1071 [3:02:01<28:04, 12.48s/it]
# Processing TRAIN (image x GSD):  87%|████████▋ | 937/1071 [3:02:06<23:17, 10.43s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 938/1071 [3:02:11<19:05,  8.61s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 939/1071 [3:02:39<31:51, 14.48s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 940/1071 [3:03:06<39:50, 18.25s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 941/1071 [3:03:19<36:10, 16.69s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 942/1071 [3:03:27<30:20, 14.11s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 943/1071 [3:03:35<26:28, 12.41s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 944/1071 [3:03:41<21:58, 10.38s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 945/1071 [3:03:45<17:56,  8.54s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 946/1071 [3:04:13<30:01, 14.41s/it]
# Processing TRAIN (image x GSD):  88%|████████▊ | 947/1071 [3:04:41<37:40, 18.23s/it]
# Processing TRAIN (image x GSD):  89%|████████▊ | 948/1071 [3:04:53<34:06, 16.64s/it]
# Processing TRAIN (image x GSD):  89%|████████▊ | 949/1071 [3:05:01<28:33, 14.05s/it]
# Processing TRAIN (image x GSD):  89%|████████▊ | 950/1071 [3:05:10<24:58, 12.39s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 951/1071 [3:05:16<20:41, 10.34s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 952/1071 [3:05:20<16:55,  8.54s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 953/1071 [3:05:48<28:23, 14.44s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 954/1071 [3:06:15<35:40, 18.29s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 955/1071 [3:06:28<32:15, 16.68s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 956/1071 [3:06:36<27:00, 14.09s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 957/1071 [3:06:45<23:30, 12.37s/it]
# Processing TRAIN (image x GSD):  89%|████████▉ | 958/1071 [3:06:50<19:30, 10.36s/it]
# Processing TRAIN (image x GSD):  90%|████████▉ | 959/1071 [3:06:55<15:53,  8.52s/it]
# Processing TRAIN (image x GSD):  90%|████████▉ | 960/1071 [3:07:23<26:34, 14.36s/it]
# Processing TRAIN (image x GSD):  90%|████████▉ | 961/1071 [3:07:50<33:15, 18.14s/it]
# Processing TRAIN (image x GSD):  90%|████████▉ | 962/1071 [3:08:03<30:09, 16.60s/it]
# Processing TRAIN (image x GSD):  90%|████████▉ | 963/1071 [3:08:11<25:20, 14.08s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 964/1071 [3:08:19<22:03, 12.37s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 965/1071 [3:08:25<18:14, 10.33s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 966/1071 [3:08:29<14:51,  8.49s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 967/1071 [3:08:58<25:24, 14.66s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 968/1071 [3:09:25<31:24, 18.30s/it]
# Processing TRAIN (image x GSD):  90%|█████████ | 969/1071 [3:09:38<28:19, 16.66s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 970/1071 [3:09:45<23:38, 14.04s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 971/1071 [3:09:54<20:36, 12.37s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 972/1071 [3:09:59<17:02, 10.32s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 973/1071 [3:10:04<13:58,  8.55s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 974/1071 [3:10:32<23:14, 14.38s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 975/1071 [3:10:59<29:09, 18.22s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 976/1071 [3:11:12<26:19, 16.63s/it]
# Processing TRAIN (image x GSD):  91%|█████████ | 977/1071 [3:11:20<22:00, 14.05s/it]
# Processing TRAIN (image x GSD):  91%|█████████▏| 978/1071 [3:11:28<19:07, 12.34s/it]
# Processing TRAIN (image x GSD):  91%|█████████▏| 979/1071 [3:11:34<15:51, 10.34s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 980/1071 [3:11:38<12:53,  8.50s/it]
# [Checkpoint] Saved partial after 140 images:
# CSV : /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.csv
# XLSX: /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels_PARTIAL.xlsx
# Processing TRAIN (image x GSD):  92%|█████████▏| 981/1071 [3:12:07<21:53, 14.59s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 982/1071 [3:12:34<27:11, 18.33s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 983/1071 [3:12:47<24:30, 16.71s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 984/1071 [3:12:55<20:29, 14.14s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 985/1071 [3:13:04<17:48, 12.43s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 986/1071 [3:13:09<14:40, 10.36s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 987/1071 [3:13:13<11:57,  8.54s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 988/1071 [3:13:42<20:04, 14.51s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 989/1071 [3:14:09<25:01, 18.32s/it]
# Processing TRAIN (image x GSD):  92%|█████████▏| 990/1071 [3:14:22<22:32, 16.70s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 991/1071 [3:14:30<18:48, 14.10s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 992/1071 [3:14:39<16:22, 12.44s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 993/1071 [3:14:44<13:30, 10.40s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 994/1071 [3:14:48<10:57,  8.55s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 995/1071 [3:15:16<18:10, 14.35s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 996/1071 [3:15:43<22:38, 18.12s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 997/1071 [3:15:56<20:25, 16.57s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 998/1071 [3:16:04<17:05, 14.04s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 999/1071 [3:16:13<14:47, 12.32s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 1000/1071 [3:16:18<12:10, 10.30s/it]
# Processing TRAIN (image x GSD):  93%|█████████▎| 1001/1071 [3:16:22<09:52,  8.46s/it]
# Processing TRAIN (image x GSD):  94%|█████████▎| 1002/1071 [3:16:50<16:27, 14.32s/it]
# Processing TRAIN (image x GSD):  94%|█████████▎| 1003/1071 [3:17:17<20:34, 18.15s/it]
# Processing TRAIN (image x GSD):  94%|█████████▎| 1004/1071 [3:17:30<18:31, 16.58s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1005/1071 [3:17:38<15:23, 13.99s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1006/1071 [3:17:47<13:21, 12.33s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1007/1071 [3:17:52<10:58, 10.29s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1008/1071 [3:17:57<08:55,  8.49s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1009/1071 [3:18:25<14:47, 14.31s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1010/1071 [3:18:52<18:28, 18.17s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1011/1071 [3:19:05<16:34, 16.57s/it]
# Processing TRAIN (image x GSD):  94%|█████████▍| 1012/1071 [3:19:13<13:46, 14.01s/it]
# Processing TRAIN (image x GSD):  95%|█████████▍| 1013/1071 [3:19:21<11:56, 12.35s/it]
# Processing TRAIN (image x GSD):  95%|█████████▍| 1014/1071 [3:19:27<09:49, 10.34s/it]
# Processing TRAIN (image x GSD):  95%|█████████▍| 1015/1071 [3:19:31<07:55,  8.49s/it]
# Processing TRAIN (image x GSD):  95%|█████████▍| 1016/1071 [3:19:59<13:09, 14.36s/it]
# Processing TRAIN (image x GSD):  95%|█████████▍| 1017/1071 [3:20:26<16:17, 18.10s/it]
# Processing TRAIN (image x GSD):  95%|█████████▌| 1018/1071 [3:20:39<14:37, 16.56s/it]
# Processing TRAIN (image x GSD):  95%|█████████▌| 1019/1071 [3:20:47<12:10, 14.05s/it]
# Processing TRAIN (image x GSD):  95%|█████████▌| 1020/1071 [3:20:55<10:30, 12.35s/it]
# Processing TRAIN (image x GSD):  95%|█████████▌| 1021/1071 [3:21:01<08:35, 10.31s/it]
# Processing TRAIN (image x GSD):  95%|█████████▌| 1022/1071 [3:21:05<06:54,  8.47s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1023/1071 [3:21:33<11:32, 14.43s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1024/1071 [3:22:00<14:16, 18.22s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1025/1071 [3:22:13<12:45, 16.63s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1026/1071 [3:22:21<10:31, 14.02s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1027/1071 [3:22:30<09:02, 12.34s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1028/1071 [3:22:35<07:22, 10.30s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1029/1071 [3:22:40<05:57,  8.50s/it]
# Processing TRAIN (image x GSD):  96%|█████████▌| 1030/1071 [3:23:07<09:47, 14.33s/it]
# Processing TRAIN (image x GSD):  96%|█████████▋| 1031/1071 [3:23:35<12:07, 18.20s/it]
# Processing TRAIN (image x GSD):  96%|█████████▋| 1032/1071 [3:23:47<10:46, 16.57s/it]
# Processing TRAIN (image x GSD):  96%|█████████▋| 1033/1071 [3:23:55<08:51, 13.99s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1034/1071 [3:24:04<07:34, 12.29s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1035/1071 [3:24:09<06:10, 10.29s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1036/1071 [3:24:14<05:01,  8.63s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1037/1071 [3:24:42<08:09, 14.40s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1038/1071 [3:25:09<09:58, 18.14s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1039/1071 [3:25:22<08:49, 16.55s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1040/1071 [3:25:30<07:14, 14.01s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1041/1071 [3:25:38<06:09, 12.32s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1042/1071 [3:25:44<04:58, 10.28s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1043/1071 [3:25:48<03:56,  8.46s/it]
# Processing TRAIN (image x GSD):  97%|█████████▋| 1044/1071 [3:26:17<06:34, 14.62s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1045/1071 [3:26:44<07:55, 18.28s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1046/1071 [3:26:57<06:56, 16.65s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1047/1071 [3:27:04<05:36, 14.02s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1048/1071 [3:27:13<04:43, 12.33s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1049/1071 [3:27:18<03:46, 10.28s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1050/1071 [3:27:23<03:02,  8.68s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1051/1071 [3:27:51<04:49, 14.49s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1052/1071 [3:28:18<05:46, 18.24s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1053/1071 [3:28:31<04:59, 16.65s/it]
# Processing TRAIN (image x GSD):  98%|█████████▊| 1054/1071 [3:28:39<03:59, 14.08s/it]
# Processing TRAIN (image x GSD):  99%|█████████▊| 1055/1071 [3:28:48<03:17, 12.36s/it]
# Processing TRAIN (image x GSD):  99%|█████████▊| 1056/1071 [3:28:53<02:35, 10.35s/it]
# Processing TRAIN (image x GSD):  99%|█████████▊| 1057/1071 [3:28:58<01:59,  8.50s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1058/1071 [3:29:26<03:06, 14.37s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1059/1071 [3:29:53<03:38, 18.20s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1060/1071 [3:30:06<03:02, 16.63s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1061/1071 [3:30:14<02:21, 14.13s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1062/1071 [3:30:22<01:52, 12.44s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1063/1071 [3:30:28<01:22, 10.37s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1064/1071 [3:30:32<00:59,  8.54s/it]
# Processing TRAIN (image x GSD):  99%|█████████▉| 1065/1071 [3:31:01<01:26, 14.50s/it]
# Processing TRAIN (image x GSD): 100%|█████████▉| 1066/1071 [3:31:28<01:31, 18.27s/it]
# Processing TRAIN (image x GSD): 100%|█████████▉| 1067/1071 [3:31:41<01:06, 16.66s/it]
# Processing TRAIN (image x GSD): 100%|█████████▉| 1068/1071 [3:31:49<00:42, 14.07s/it]
# Processing TRAIN (image x GSD): 100%|█████████▉| 1069/1071 [3:31:57<00:24, 12.39s/it]
# Processing TRAIN (image x GSD): 100%|█████████▉| 1070/1071 [3:32:03<00:10, 10.35s/it]
# Processing TRAIN (image x GSD): 100%|██████████| 1071/1071 [3:32:07<00:00, 11.88s/it]
#     image_name  gsd_m_per_px  resize_factor  tile_size  overlap  tile_batch  \
# 0  austin1.tif          0.10       3.000000       1024      0.1          16
# 1  austin1.tif          0.20       1.500000       1024      0.1          16
# 2  austin1.tif          0.29       1.034483       1024      0.1          16
# 3  austin1.tif          0.40       0.750000       1024      0.1          16
# 4  austin1.tif          0.50       0.600000       1024      0.1          16
#
#    conf_primary  count_primary  conf_fallback  count_fallback  ...  \
# 0           0.1           1747           0.01               0  ...
# 1           0.1           1949           0.01               0  ...
# 2           0.1           1964           0.01               0  ...
# 3           0.1           1525           0.01               0  ...
# 4           0.1            742           0.01               0  ...
#
#    mean_wid_s2_px  mean_sqrtLW_s2_px  count_s2  med_len_s3_px  med_wid_s3_px  \
# 0       21.962753          32.549480      2026      48.281250      21.770833
# 1       11.006971          16.367126      1607      26.875000      12.317708
# 2        8.251802          12.108937       455      16.953125       7.937500
# 3        6.352423           9.273932        48      12.656250       5.929688
# 4             NaN                NaN         0      10.515625       4.929688
#
#    med_sqrtLW_s3_px  mean_len_s3_px  mean_wid_s3_px  mean_sqrtLW_s3_px  \
# 0         32.393443       48.464661       21.748509          32.435560
# 1         18.017276       26.850446       12.314732          18.167852
# 2         11.603787       17.111334        7.918936          11.628786
# 3          8.636884       12.766327        5.929500           8.692733
# 4          7.178051       10.506768        4.937602           7.196582
#
#    count_s3
# 0      1933
# 1        35
# 2      1943
# 3      1247
# 4       363
#
# [5 rows x 37 columns]
# Done. Rows: 1071
# Saved FINAL:
# CSV : /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels.csv
# XLSX: /content/drive/MyDrive/train_vehicle_stats_adaptive_3scale_pixels.xlsx
